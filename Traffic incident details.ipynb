# %%
import requests

# %%
response=requests.get('https://api.tomtom.com/traffic/services/4/incidentDetails/s3/6841263.950712,511972.674418,6886056.049288,582676.925582/11/1335294634919/json?key=Av7CjQlvKsUKbCwpXdKYPVsgOjvccI8m',
                params={'baseURL':'api.tomtom.com','versionNumber':'4','style':'s0',
                'boundingBox':'6841263.950712,511972.674418,6886056.049288,582676.925582',
                'zoom':10,'trafficModelID':'0','format':'json','key':'Av7CjQlvKsUKbCwpXdKYPVsgOjvccI8m'})

# %%
response.headers
# Out:
# {'Date': 'Fri, 17 Jul 2020 16:01:24 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Tracking-ID': 'cc8b79d5-62dc-4c96-ba17-146ab343ed93', 'Access-Control-Allow-Origin': '*', 'Cache-Control': 'private, no-cache, no-store, max-age=0, must-revalidate', 'Content-Language': 'en', 'TrafficModelID': '1595001640', 'Expires': 'Fri, 17 Jul 2020 16:01:30 GMT', 'Content-Encoding': 'gzip', 'Strict-Transport-Security': 'max-age=15724800; includeSubDomains'}

# %%
response.json()
# Out:
# {'tm': {'@id': '1595001640',
#   'poi': [{'id': 'CLUSTER_78948',
#     'p': {'x': 511997.259333, 'y': 6884625.9094498},
#     'ic': 8,
#     'ty': 0,
#     'cbl': {'x': 511661.6996591, 'y': 6883506.8235823},
#     'ctr': {'x': 512557.4460845, 'y': 6884953.7246494},
#     'cs': 6,
#     'l': 1828},
#    {'id': 'CLUSTER_78962',
#     'p': {'x': 515033.2145588, 'y': 6847438.4367568},
#     'ic': 8,
#     'ty': 0,
#     'cbl': {'x': 514558.5435989, 'y': 6847391.242117},
#     'ctr': {'x': 516260.9096804, 'y': 6847476.6179481},
#     'cs': 4,
#     'l': 679},
#    {'id': 'CLUSTER_78964',
#     'p': {'x': 515529.6073696, 'y': 6868722.6967831},
#     'ic': 13,
#     'ty': 1,
#     'cbl': {'x': 515511.9163777, 'y': 6868337.2738915},
#     'ctr': {'x': 515547.2983615, 'y': 6869108.1196747},
#     'cs': 2,
#     'l': 285},
#    {'id': 'CLUSTER_78966',
#     'p': {'x': 516363.8458738, 'y': 6881419.6317735},
#     'ic': 8,
#     'ty': 0,
#     'cbl': {'x': 516318.0881606, 'y': 6881120.8070337},
# ...
